# %% [markdown]
# # Imputation & Forecasting of time-series using a custom architecture based on CSDI
#
# The implementation uses PyTorch. It is based on the original CSDI implementation, but modified for our needs.
#
# OPE (ANDRA) data data

# %%
# !nvidia-smi
# Out:
# Mon Jun 29 11:57:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.20             Driver Version: 580.126.20     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 4500 Blac...    On  |   00000000:81:00.0 Off |                  Off |
# | 30%   30C    P1             29W /  200W |     543MiB /  32623MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            8246      C   /usr/bin/python                         270MiB |
# |    0   N/A  N/A           10407      C   /usr/bin/python                         258MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# Libraries imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import datetime
import json
import yaml
import os
import sys

# Our code import
sys.path.append("..")
sys.path.append(os.path.abspath("../models"))

from models.custom_main import Custom_CSDI_WaterQual
from utils import *
from dataset_synthetic import get_dataloader

# %%
# Set seed
rng = np.random.RandomState(1)

# %% [markdown]
# ## Load Data

# %%
#Load all data on GPU, will run on cpu without modification if gpu is not available

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_loader, valid_loader, test_loader = get_dataloader("../data/multivariate_synthetic.csv", device=device, batch_size=8)
# Out:
# Loaded SAGD training data with shape:  (100000, 25)
# Training dataset len:  4128
# Loaded SAGD training data with shape:  (100000, 25)
# Valid dataset len:  15
# Loaded SAGD training data with shape:  (100000, 25)
# Test dataset len:  21

# %% [markdown]
# ## Model Definition and Training

# %%
data_dim = 25

# %%
# Load the config

# My own config for synthetic
path = "../config/synthetic_imputation.yaml"

with open(path, "r") as f:
    config = yaml.safe_load(f)

# The only thing I overwrite, so I can change epochs for my tests
config["train"]["epochs"] = 100

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") 
foldername = (
    "./save/validationindex" + "_" + current_time
)

os.makedirs(foldername, exist_ok=True)
with open(foldername + "config.json", "w") as f:
    json.dump(config, f, indent=4)

# %%
model = Custom_CSDI_WaterQual(config, device, target_dim=data_dim).to(device)
# Out:
# /workspace/last_last_version/notebooks/../models/custom_architecture.py:23: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   return nn.TransformerEncoder(encoder_layer, num_layers=layers)

# %%
do_train = True

if do_train:
# define and train mode. keep an history for monitoring
    history  = {}

    # It returns history, which we don't need really
    _ = train(
        model,
        config["train"],
        train_loader,
        valid_loader=valid_loader,
        foldername=foldername,
        history=history)
# Out:
# 100%|██████████| 516/516 [00:15<00:00, 32.62it/s, avg_epoch_loss=0.133, epoch=0]
# 100%|██████████| 516/516 [00:14<00:00, 35.30it/s, avg_epoch_loss=0.0491, epoch=1]
# 100%|██████████| 516/516 [00:13<00:00, 38.28it/s, avg_epoch_loss=0.036, epoch=2]
# 100%|██████████| 516/516 [00:13<00:00, 38.12it/s, avg_epoch_loss=0.0326, epoch=3]
# 100%|██████████| 516/516 [00:13<00:00, 38.29it/s, avg_epoch_loss=0.0307, epoch=4]
# 100%|██████████| 516/516 [00:13<00:00, 38.33it/s, avg_epoch_loss=0.027, epoch=5]
# 100%|██████████| 516/516 [00:13<00:00, 38.27it/s, avg_epoch_loss=0.0262, epoch=6]
# 100%|██████████| 516/516 [00:13<00:00, 38.20it/s, avg_epoch_loss=0.0276, epoch=7]
# 100%|██████████| 516/516 [00:13<00:00, 38.24it/s, avg_epoch_loss=0.0232, epoch=8]
# 100%|██████████| 516/516 [00:14<00:00, 36.77it/s, avg_epoch_loss=0.026, epoch=9]
# 100%|██████████| 516/516 [00:14<00:00, 34.99it/s, avg_epoch_loss=0.0233, epoch=10]
# 100%|██████████| 516/516 [00:14<00:00, 34.95it/s, avg_epoch_loss=0.0258, epoch=11]
# 100%|██████████| 516/516 [00:13<00:00, 38.38it/s, avg_epoch_loss=0.0246, epoch=12]
# 100%|██████████| 516/516 [00:13<00:00, 38.27it/s, avg_epoch_loss=0.0248, epoch=13]
# 100%|██████████| 516/516 [00:15<00:00, 34.37it/s, avg_epoch_loss=0.0242, epoch=14]
# 100%|██████████| 516/516 [00:14<00:00, 35.00it/s, avg_epoch_loss=0.0248, epoch=15]
# 100%|██████████| 516/516 [00:14<00:00, 34.78it/s, avg_epoch_loss=0.0221, epoch=16]
# 100%|██████████| 516/516 [00:14<00:00, 34.73it/s, avg_epoch_loss=0.0218, epoch=17]
# 100%|██████████| 516/516 [00:14<00:00, 34.73it/s, avg_epoch_loss=0.022, epoch=18]
# 100%|██████████| 516/516 [00:14<00:00, 35.03it/s, avg_epoch_loss=0.021, epoch=19]
# 100%|██████████| 2/2 [00:00<00:00, 88.98it/s, valid_avg_epoch_loss=0.00648, epoch=19]
#  best loss is updated to  0.006481226999312639 at 19
# 100%|██████████| 516/516 [00:13<00:00, 37.30it/s, avg_epoch_loss=0.0221, epoch=20]
# 100%|██████████| 516/516 [00:13<00:00, 37.40it/s, avg_epoch_loss=0.0241, epoch=21]
# 100%|██████████| 516/516 [00:13<00:00, 37.19it/s, avg_epoch_loss=0.0214, epoch=22]
# 100%|██████████| 516/516 [00:14<00:00, 36.40it/s, avg_epoch_loss=0.0229, epoch=23]
# 100%|██████████| 516/516 [00:14<00:00, 34.72it/s, avg_epoch_loss=0.0225, epoch=24]
# 100%|██████████| 516/516 [00:14<00:00, 34.69it/s, avg_epoch_loss=0.0207, epoch=25]
# 100%|██████████| 516/516 [00:14<00:00, 34.57it/s, avg_epoch_loss=0.0223, epoch=26]
# 100%|██████████| 516/516 [00:14<00:00, 34.60it/s, avg_epoch_loss=0.0211, epoch=27]
# 100%|██████████| 516/516 [00:14<00:00, 34.74it/s, avg_epoch_loss=0.021, epoch=28]
# 100%|██████████| 516/516 [00:14<00:00, 34.79it/s, avg_epoch_loss=0.0202, epoch=29]
# 100%|██████████| 516/516 [00:14<00:00, 34.62it/s, avg_epoch_loss=0.0196, epoch=30]
# 100%|██████████| 516/516 [00:14<00:00, 34.72it/s, avg_epoch_loss=0.0194, epoch=31]
# 100%|██████████| 516/516 [00:14<00:00, 34.80it/s, avg_epoch_loss=0.0219, epoch=32]
# 100%|██████████| 516/516 [00:14<00:00, 35.09it/s, avg_epoch_loss=0.02, epoch=33]
# 100%|██████████| 516/516 [00:14<00:00, 34.85it/s, avg_epoch_loss=0.0197, epoch=34]
# 100%|██████████| 516/516 [00:14<00:00, 36.43it/s, avg_epoch_loss=0.0193, epoch=35]
# 100%|██████████| 516/516 [00:13<00:00, 38.04it/s, avg_epoch_loss=0.0191, epoch=36]
# 100%|██████████| 516/516 [00:13<00:00, 38.32it/s, avg_epoch_loss=0.02, epoch=37]
# 100%|██████████| 516/516 [00:13<00:00, 38.17it/s, avg_epoch_loss=0.0205, epoch=38]
# 100%|██████████| 516/516 [00:13<00:00, 38.24it/s, avg_epoch_loss=0.0199, epoch=39]
# 100%|██████████| 2/2 [00:00<00:00, 113.67it/s, valid_avg_epoch_loss=0.00286, epoch=39]
#  best loss is updated to  0.0028635025955736637 at 39
# 100%|██████████| 516/516 [00:13<00:00, 38.29it/s, avg_epoch_loss=0.0208, epoch=40]
# 100%|██████████| 516/516 [00:13<00:00, 38.14it/s, avg_epoch_loss=0.0189, epoch=41]
# 100%|██████████| 516/516 [00:13<00:00, 38.15it/s, avg_epoch_loss=0.02, epoch=42]
# 100%|██████████| 516/516 [00:13<00:00, 38.09it/s, avg_epoch_loss=0.018, epoch=43]
# 100%|██████████| 516/516 [00:13<00:00, 38.34it/s, avg_epoch_loss=0.022, epoch=44]
# 100%|██████████| 516/516 [00:13<00:00, 38.07it/s, avg_epoch_loss=0.0192, epoch=45]
# 100%|██████████| 516/516 [00:13<00:00, 38.25it/s, avg_epoch_loss=0.0202, epoch=46]
# 100%|██████████| 516/516 [00:13<00:00, 38.03it/s, avg_epoch_loss=0.0191, epoch=47]
# 100%|██████████| 516/516 [00:13<00:00, 38.25it/s, avg_epoch_loss=0.0172, epoch=48]
# 100%|██████████| 516/516 [00:13<00:00, 38.13it/s, avg_epoch_loss=0.0177, epoch=49]
# 100%|██████████| 516/516 [00:13<00:00, 38.25it/s, avg_epoch_loss=0.0186, epoch=50]
# 100%|██████████| 516/516 [00:13<00:00, 37.16it/s, avg_epoch_loss=0.0212, epoch=51]
# 100%|██████████| 516/516 [00:14<00:00, 34.60it/s, avg_epoch_loss=0.0187, epoch=52]
# 100%|██████████| 516/516 [00:14<00:00, 34.77it/s, avg_epoch_loss=0.018, epoch=53]
# 100%|██████████| 516/516 [00:13<00:00, 37.43it/s, avg_epoch_loss=0.0199, epoch=54]
# 100%|██████████| 516/516 [00:13<00:00, 38.22it/s, avg_epoch_loss=0.0177, epoch=55]
# 100%|██████████| 516/516 [00:13<00:00, 38.10it/s, avg_epoch_loss=0.0204, epoch=56]
# 100%|██████████| 516/516 [00:13<00:00, 37.96it/s, avg_epoch_loss=0.0185, epoch=57]
# 100%|██████████| 516/516 [00:13<00:00, 37.83it/s, avg_epoch_loss=0.0194, epoch=58]
# 100%|██████████| 516/516 [00:13<00:00, 38.13it/s, avg_epoch_loss=0.0179, epoch=59]
# 100%|██████████| 2/2 [00:00<00:00, 103.90it/s, valid_avg_epoch_loss=0.0186, epoch=59]
# 100%|██████████| 516/516 [00:13<00:00, 36.88it/s, avg_epoch_loss=0.0202, epoch=60]
# 100%|██████████| 516/516 [00:14<00:00, 36.26it/s, avg_epoch_loss=0.0175, epoch=61]
# 100%|██████████| 516/516 [00:14<00:00, 34.72it/s, avg_epoch_loss=0.0169, epoch=62]
# 100%|██████████| 516/516 [00:14<00:00, 34.98it/s, avg_epoch_loss=0.0185, epoch=63]
# 100%|██████████| 516/516 [00:14<00:00, 36.00it/s, avg_epoch_loss=0.0189, epoch=64]
# 100%|██████████| 516/516 [00:13<00:00, 38.18it/s, avg_epoch_loss=0.0185, epoch=65]
# 100%|██████████| 516/516 [00:13<00:00, 38.40it/s, avg_epoch_loss=0.0191, epoch=66]
# 100%|██████████| 516/516 [00:13<00:00, 36.96it/s, avg_epoch_loss=0.0176, epoch=67]
# 100%|██████████| 516/516 [00:14<00:00, 34.78it/s, avg_epoch_loss=0.0202, epoch=68]
# 100%|██████████| 516/516 [00:14<00:00, 34.77it/s, avg_epoch_loss=0.0192, epoch=69]
# 100%|██████████| 516/516 [00:16<00:00, 32.11it/s, avg_epoch_loss=0.0183, epoch=70]
# 100%|██████████| 516/516 [00:15<00:00, 33.70it/s, avg_epoch_loss=0.0197, epoch=71]
# 100%|██████████| 516/516 [00:15<00:00, 33.47it/s, avg_epoch_loss=0.0203, epoch=72]
# 100%|██████████| 516/516 [00:15<00:00, 32.96it/s, avg_epoch_loss=0.0178, epoch=73]
# 100%|██████████| 516/516 [00:16<00:00, 31.95it/s, avg_epoch_loss=0.0188, epoch=74]
# 100%|██████████| 516/516 [00:16<00:00, 32.12it/s, avg_epoch_loss=0.0166, epoch=75]
# 100%|██████████| 516/516 [00:16<00:00, 31.91it/s, avg_epoch_loss=0.017, epoch=76]
# 100%|██████████| 516/516 [00:15<00:00, 33.79it/s, avg_epoch_loss=0.0162, epoch=77]
# 100%|██████████| 516/516 [00:14<00:00, 34.88it/s, avg_epoch_loss=0.0174, epoch=78]
# 100%|██████████| 516/516 [00:15<00:00, 32.55it/s, avg_epoch_loss=0.0179, epoch=79]
# 100%|██████████| 2/2 [00:00<00:00, 94.70it/s, valid_avg_epoch_loss=0.00801, epoch=79]
# 100%|██████████| 516/516 [00:16<00:00, 32.10it/s, avg_epoch_loss=0.0186, epoch=80]
# 100%|██████████| 516/516 [00:15<00:00, 33.02it/s, avg_epoch_loss=0.015, epoch=81]
# 100%|██████████| 516/516 [00:15<00:00, 33.93it/s, avg_epoch_loss=0.0158, epoch=82]
# 100%|██████████| 516/516 [00:15<00:00, 34.20it/s, avg_epoch_loss=0.0134, epoch=83]
# 100%|██████████| 516/516 [00:14<00:00, 34.51it/s, avg_epoch_loss=0.0167, epoch=84]
# 100%|██████████| 516/516 [00:14<00:00, 34.63it/s, avg_epoch_loss=0.0172, epoch=85]
# 100%|██████████| 516/516 [00:15<00:00, 34.20it/s, avg_epoch_loss=0.0168, epoch=86]
# 100%|██████████| 516/516 [00:15<00:00, 34.22it/s, avg_epoch_loss=0.0143, epoch=87]
# 100%|██████████| 516/516 [00:14<00:00, 34.60it/s, avg_epoch_loss=0.0162, epoch=88]
# 100%|██████████| 516/516 [00:15<00:00, 34.04it/s, avg_epoch_loss=0.0152, epoch=89]
# 100%|██████████| 516/516 [00:15<00:00, 34.37it/s, avg_epoch_loss=0.0164, epoch=90]
# 100%|██████████| 516/516 [00:15<00:00, 34.18it/s, avg_epoch_loss=0.0157, epoch=91]
# 100%|██████████| 516/516 [00:15<00:00, 34.30it/s, avg_epoch_loss=0.0168, epoch=92]
# 100%|██████████| 516/516 [00:15<00:00, 34.22it/s, avg_epoch_loss=0.0156, epoch=93]
# 100%|██████████| 516/516 [00:14<00:00, 34.97it/s, avg_epoch_loss=0.0178, epoch=94]
# 100%|██████████| 516/516 [00:13<00:00, 37.60it/s, avg_epoch_loss=0.0153, epoch=95]
# 100%|██████████| 516/516 [00:13<00:00, 37.41it/s, avg_epoch_loss=0.0151, epoch=96]
# 100%|██████████| 516/516 [00:13<00:00, 37.60it/s, avg_epoch_loss=0.0161, epoch=97]
# 100%|██████████| 516/516 [00:14<00:00, 35.73it/s, avg_epoch_loss=0.0174, epoch=98]
# 100%|██████████| 516/516 [00:15<00:00, 34.31it/s, avg_epoch_loss=0.0161, epoch=99]
# 100%|██████████| 2/2 [00:00<00:00, 102.73it/s, valid_avg_epoch_loss=0.0437, epoch=99]

# %%
if do_train:
    torch.save(model.state_dict(), "../saved_weights/custom_synthe.pt")
else:
    model.load_state_dict(torch.load("../saved_weights/custom_synthe.pt", weights_only=True))
    model.to(device)

# %%
param_size = 0
for param in model.parameters():
    param_size += param.nelement() * param.element_size()
buffer_size = 0
for buffer in model.buffers():
    buffer_size += buffer.nelement() * buffer.element_size()

size_all_mb = (param_size + buffer_size) / 1024**2
print('model size: {:.3f}MB'.format(size_all_mb))
# Out:
# model size: 2.010MB

# %% [markdown]
# ## Evaluations and Tests

# %% [markdown]
# ### Single generation test

# %%
from utils import plot_single_imputation_results

# %%
batch = next(iter(test_loader))

device = model.device
observed_mask = batch['observed_mask'].to(device, dtype=torch.float32)
observed_data = batch['observed_data'].to(device, dtype=torch.float32)
timestamps = batch['timepoints'].to(device)  # Souvent nécessaire pour le modèle

observed_mask_forecast = observed_mask.clone()
observed_mask_forecast[:, 25:] = 0.

observed_data_masked = observed_data * observed_mask_forecast

# GENERATE WITH MODEL
generated = model.impute(
    observed_data_masked, 
    observed_mask_forecast, 
    n_samples=1, 
    timestamps=timestamps
)
# Out:
# /workspace/last_last_version/notebooks/../models/custom_main.py:261: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   observed_tp = torch.tensor(observed_tp, dtype=torch.float32).to(self.device)

# %%
# Bring back the data on the cpu for vizualization

generated_test = generated.cpu().permute([0, 1, 3, 2]).numpy()[0].squeeze()
observations = observed_data[0].squeeze().cpu().numpy()
mask = observed_mask_forecast[0].squeeze().cpu().numpy()
timestamps = batch['timepoints'][0].squeeze().numpy()

generated_test.shape, observations.shape, mask.shape, timestamps.shape
# Out:
# ((72, 25), (72, 25), (72, 25), (72,))

# %%
plot_single_imputation_results(generated_test, mask)

# %% [markdown]
# ## Evaluate Forecasting

# %% [markdown]
# ### Forecasting Metrics

# %%
import numpy as np
from collections import defaultdict

horizons = [6, 12, 18]
n_trials = 5

results = {h: defaultdict(list) for h in horizons}

# Run trials
for trial in range(n_trials):
    print(f"Trial {trial+1}/{n_trials}")
    
    for h in horizons:
        out = evaluate_forecasting(
            model,
            test_loader,
            prediction_horizon=h,
            nsample=100,
        )
        
        for key, value in out.items():
            results[h][key].append(value)

# Compute mean & std over trials
print("\n=== Forecasting Results ===")
for h in horizons:
    print(f"\nHorizon: {h}")
    
    for metric in results[h]:
        values = np.array(results[h][metric])
        mean = values.mean()
        std = values.std()
        
        print(f"{metric}: {mean:.4f} ± {std:.4f}")
# Out:
# Trial 1/5
# 100%|██████████| 3/3 [03:36<00:00, 72.29s/it, rmse_total=0.0492, mae_total=0.0215, smape_total=7.23, batch_no=3]
# 100%|██████████| 3/3 [03:36<00:00, 72.14s/it, rmse_total=0.0572, mae_total=0.0271, smape_total=8.73, batch_no=3]
# 100%|██████████| 3/3 [03:38<00:00, 72.98s/it, rmse_total=0.0721, mae_total=0.034, smape_total=10.2, batch_no=3]
# Trial 2/5
# 100%|██████████| 3/3 [03:38<00:00, 72.83s/it, rmse_total=0.0494, mae_total=0.0215, smape_total=7.21, batch_no=3]
# 100%|██████████| 3/3 [03:38<00:00, 72.79s/it, rmse_total=0.0573, mae_total=0.027, smape_total=8.67, batch_no=3]
# 100%|██████████| 3/3 [03:37<00:00, 72.57s/it, rmse_total=0.0724, mae_total=0.034, smape_total=10.2, batch_no=3]
# Trial 3/5
# 100%|██████████| 3/3 [03:38<00:00, 72.72s/it, rmse_total=0.0493, mae_total=0.0215, smape_total=7.21, batch_no=3]
# 100%|██████████| 3/3 [03:40<00:00, 73.62s/it, rmse_total=0.0571, mae_total=0.0269, smape_total=8.7, batch_no=3]
# 100%|██████████| 3/3 [03:41<00:00, 73.68s/it, rmse_total=0.0727, mae_total=0.0341, smape_total=10.2, batch_no=3]
# Trial 4/5
# 100%|██████████| 3/3 [03:41<00:00, 73.76s/it, rmse_total=0.0493, mae_total=0.0215, smape_total=7.24, batch_no=3]
# 100%|██████████| 3/3 [03:39<00:00, 73.23s/it, rmse_total=0.0571, mae_total=0.027, smape_total=8.68, batch_no=3]
# 100%|██████████| 3/3 [03:42<00:00, 74.01s/it, rmse_total=0.0726, mae_total=0.0341, smape_total=10.2, batch_no=3]
# Trial 5/5
# 100%|██████████| 3/3 [03:38<00:00, 72.68s/it, rmse_total=0.0493, mae_total=0.0215, smape_total=7.25, batch_no=3]
# 100%|██████████| 3/3 [03:36<00:00, 72.08s/it, rmse_total=0.057, mae_total=0.0269, smape_total=8.7, batch_no=3]
# 100%|██████████| 3/3 [03:38<00:00, 72.80s/it, rmse_total=0.0726, mae_total=0.0341, smape_total=10.2, batch_no=3]
# === Forecasting Results ===
#
# Horizon: 6
# rmse: 0.0493 ± 0.0001
# mae: 0.0215 ± 0.0000
# smape: 7.2293 ± 0.0138
# CRPS: 0.0530 ± 0.0002
# CRPS_sum: 0.0038 ± 0.0000
#
# Horizon: 12
# rmse: 0.0571 ± 0.0001
# mae: 0.0270 ± 0.0001
# smape: 8.6948 ± 0.0195
# CRPS: 0.0650 ± 0.0004
# CRPS_sum: 0.0092 ± 0.0001
#
# Horizon: 18
# rmse: 0.0725 ± 0.0002
# mae: 0.0340 ± 0.0000
# smape: 10.1960 ± 0.0170
# CRPS: 0.0830 ± 0.0006
# CRPS_sum: 0.0177 ± 0.0002

# %% [markdown]
# ### Forecasting Visualization

# %%
batch = next(iter(test_loader))

device = model.device
observed_mask = batch['observed_mask'].to(device, dtype=torch.float32)
real_data = batch['observed_data'].to(device, dtype=torch.float32)
timestamps = batch['timepoints'].to(device)  # Souvent nécessaire pour le modèle

observed_mask_forecast = observed_mask.clone()
observed_mask_forecast[:, 18:] = 0.

observed_data_masked = observed_data * observed_mask_forecast

# GENERATE WITH MODEL
generated = model.impute(real_data, observed_mask_forecast, n_samples=100, timestamps=batch['timepoints'])

# %%
dataind = 4 # Modify to visualize a different realization
multivariate_visualize(dataind, generated, real_data, observed_mask, observed_mask_forecast)
# Out:
# (<Figure size 3000x2000 with 80 Axes>,
#  array([[<Axes: ylabel='value'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='value'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='value'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %% [markdown]
# ## Evaluate Imputation

# %% [markdown]
# ### Imputation Metrics

# %%
import numpy as np
from collections import defaultdict

ratios = [0.25, 0.50, 0.75, 0.90]
n_trials = 5

results = {r: defaultdict(list) for r in ratios}

# Run trials
for trial in range(n_trials):
    print(f"Trial {trial+1}/{n_trials}")
    
    for seed, r in enumerate(ratios):
        out = evaluate_imputation(
            model,
            test_loader,
            ratio_missing=r,
            nsample=100,
            seed=seed,
        )
        
        for key, value in out.items():
            results[r][key].append(value)

# Compute mean & std over trials
print("\n=== Imputation Results ===")
for r in ratios:
    print(f"\nMissing Ratio: {r}")
    
    for metric in results[r]:
        values = np.array(results[r][metric])
        mean = values.mean()
        std = values.std()
        
        print(f"{metric}: {mean:.4f} ± {std:.4f}")
# Out:
# Trial 1/5
# 100%|██████████| 3/3 [03:38<00:00, 72.77s/it, rmse_total=0.0123, mae_total=0.00976, smape_total=4.44, batch_no=3]
# 100%|██████████| 3/3 [03:39<00:00, 73.16s/it, rmse_total=0.0132, mae_total=0.0104, smape_total=4.66, batch_no=3]
# 100%|██████████| 3/3 [03:40<00:00, 73.41s/it, rmse_total=0.0182, mae_total=0.0123, smape_total=5.37, batch_no=3]
# 100%|██████████| 3/3 [03:39<00:00, 73.16s/it, rmse_total=0.028, mae_total=0.0179, smape_total=7.8, batch_no=3]
# Trial 2/5
# 100%|██████████| 3/3 [03:37<00:00, 72.54s/it, rmse_total=0.0123, mae_total=0.00974, smape_total=4.42, batch_no=3]
# 100%|██████████| 3/3 [03:37<00:00, 72.50s/it, rmse_total=0.0132, mae_total=0.0104, smape_total=4.66, batch_no=3]
# 100%|██████████| 3/3 [03:39<00:00, 73.23s/it, rmse_total=0.0185, mae_total=0.0124, smape_total=5.38, batch_no=3]
# 100%|██████████| 3/3 [03:37<00:00, 72.42s/it, rmse_total=0.0283, mae_total=0.018, smape_total=7.85, batch_no=3]
# Trial 3/5
# 100%|██████████| 3/3 [03:39<00:00, 73.00s/it, rmse_total=0.0123, mae_total=0.00971, smape_total=4.42, batch_no=3]
# 100%|██████████| 3/3 [03:38<00:00, 72.72s/it, rmse_total=0.0133, mae_total=0.0104, smape_total=4.66, batch_no=3]
# 100%|██████████| 3/3 [03:40<00:00, 73.53s/it, rmse_total=0.0184, mae_total=0.0123, smape_total=5.38, batch_no=3]
# 100%|██████████| 3/3 [03:41<00:00, 73.85s/it, rmse_total=0.0283, mae_total=0.018, smape_total=7.9, batch_no=3]
# Trial 4/5
# 100%|██████████| 3/3 [03:40<00:00, 73.47s/it, rmse_total=0.0123, mae_total=0.00974, smape_total=4.43, batch_no=3]
# 100%|██████████| 3/3 [03:37<00:00, 72.57s/it, rmse_total=0.0133, mae_total=0.0104, smape_total=4.65, batch_no=3]
# 100%|██████████| 3/3 [03:37<00:00, 72.36s/it, rmse_total=0.0182, mae_total=0.0123, smape_total=5.38, batch_no=3]
# 100%|██████████| 3/3 [03:38<00:00, 72.99s/it, rmse_total=0.0282, mae_total=0.0179, smape_total=7.84, batch_no=3]
# Trial 5/5
# 100%|██████████| 3/3 [03:36<00:00, 72.32s/it, rmse_total=0.0124, mae_total=0.00977, smape_total=4.45, batch_no=3]
# 100%|██████████| 3/3 [03:36<00:00, 72.16s/it, rmse_total=0.0132, mae_total=0.0104, smape_total=4.64, batch_no=3]
# 100%|██████████| 3/3 [03:36<00:00, 72.12s/it, rmse_total=0.0184, mae_total=0.0123, smape_total=5.37, batch_no=3]
# 100%|██████████| 3/3 [03:35<00:00, 72.00s/it, rmse_total=0.0279, mae_total=0.0179, smape_total=7.87, batch_no=3]
# === Imputation Results ===
#
# Missing Ratio: 0.25
# rmse: 0.0123 ± 0.0000
# mae: 0.0097 ± 0.0000
# smape: 4.4322 ± 0.0095
# CRPS: 0.0215 ± 0.0000
# CRPS_sum: 0.0014 ± 0.0000
#
# Missing Ratio: 0.5
# rmse: 0.0132 ± 0.0000
# mae: 0.0104 ± 0.0000
# smape: 4.6543 ± 0.0061
# CRPS: 0.0229 ± 0.0000
# CRPS_sum: 0.0028 ± 0.0000
#
# Missing Ratio: 0.75
# rmse: 0.0183 ± 0.0001
# mae: 0.0123 ± 0.0000
# smape: 5.3764 ± 0.0064
# CRPS: 0.0269 ± 0.0000
# CRPS_sum: 0.0058 ± 0.0000
#
# Missing Ratio: 0.9
# rmse: 0.0281 ± 0.0002
# mae: 0.0180 ± 0.0000
# smape: 7.8519 ± 0.0314
# CRPS: 0.0387 ± 0.0001
# CRPS_sum: 0.0141 ± 0.0001

# %% [markdown]
# ### Imputation Visualization

# %%
# We only need one batch, so fetch it directly without a full loop
batch = next(iter(test_loader))

observed_mask = batch['observed_mask']
real_data = batch['observed_data']

# Calculate exact number of timesteps to retain
ratio_to_keep = 0.45  # 55% missing
num_timesteps = observed_mask.shape[1]
timesteps_to_keep = int(ratio_to_keep * num_timesteps)

# Vectorized random masking: Generate random noise matching the time and channel dimensions
# & find the threshold value for each channel to keep exactly the top 'timesteps_to_keep'
noise = torch.rand(observed_mask.shape[1], observed_mask.shape[2], device=observed_mask.device)
thresholds = torch.topk(noise, k=timesteps_to_keep, dim=0).values[-1, :]

# Create the imputation mask entirely in PyTorch
random_mask = noise >= thresholds
observed_mask_imputation = observed_mask * random_mask.unsqueeze(0)

# Prepare inputs for the model
observed_data = real_data * observed_mask_imputation

observed_mask_imputation = observed_mask_imputation.to(model.device).float()
observed_data = observed_data.to(model.device).float()

# Inference
# GENERATE WITH MODEL
generated = model.impute(
    observed_data, 
    observed_mask_imputation, 
    n_samples=100, 
    timestamps=batch['timepoints']
)

# %%
multivariate_visualize(dataind, generated, real_data, observed_mask, observed_mask_imputation)
# Out:
# (<Figure size 3000x2000 with 80 Axes>,
#  array([[<Axes: ylabel='value'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='value'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='value'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >, <Axes: >]], dtype=object))
